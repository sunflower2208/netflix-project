# %%
import pandas as pd

# %%
df_input = pd.read_pickle("netflix_prize.pkl")
df_mt = pd.read_csv("netflix-prize\movie_titles.csv", header=None, names=["movieID"])

# %%
df_input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100480507 entries, 0 to 100480506
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   index       int64
#  1   userID      object
#  2   rating      float64
#  3   ratingDate  object
#  4   movieID     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 3.7+ GB

# %%
df_mt.head()
# Out:
#                                movieID
# 0               1;2003;Dinosaur Planet
# 1    2;2004;Isle of Man TT 2004 Review
# 2                     3;1997;Character
# 3  4;1994;Paula Abdul's Get Up & Dance
# 4      5;2004;The Rise and Fall of ECW

# %% [markdown]
# ### Splitting the contents of 'movieID' column to get movie ID, its release year and the title

# %%
df_mt['movieID'] = df_mt['movieID'].apply(lambda x: list(x.split(";")))
df_mt["releaseYear"] = df_mt['movieID'].apply(lambda x: x[1])
df_mt["title"] = df_mt['movieID'].apply(lambda x: x[2])
df_mt["movieID"] = df_mt['movieID'].apply(lambda x: x[0])

# %%
## Get the content type from title (e.g. TV Shows have "Series" or "Season" the title)
df_mt['type'] = df_mt["title"].apply(lambda x: "tv show" if ": series " in x.lower() or ": season " in x.lower() else "movie")
df_mt['title'] = df_mt['title'].apply(lambda x: x[:x.lower().find(": s")] if ": series " in x.lower() or ": season " in x.lower() else x)
df_mt.head()
# Out:
#   movieID releaseYear                         title   type
# 0       1        2003               Dinosaur Planet  movie
# 1       2        2004    Isle of Man TT 2004 Review  movie
# 2       3        1997                     Character  movie
# 3       4        1994  Paula Abdul's Get Up & Dance  movie
# 4       5        2004      The Rise and Fall of ECW  movie

# %%
df_input.head()
# Out:
#    index   userID  rating  ratingDate movieID
# 0      1  1488844     3.0  2005-09-06       1
# 1      2   822109     5.0  2005-05-13       1
# 2      3   885013     4.0  2005-10-19       1
# 3      4    30878     4.0  2005-12-26       1
# 4      5   823519     3.0  2004-05-03       1

# %% [markdown]
# ### Get keywords from movie title

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
 
ps = PorterStemmer()
stop_words = set(stopwords.words('english'))

df_mt['keywords'] = ""

for i in range(len(df_mt)):
    words = word_tokenize(df_mt['title'][i])
    filtered_words = [word for word in words if word.isalpha() and not word.lower() in stop_words]
    df_mt['keywords'][i] = [ps.stem(word) for word in filtered_words]

# %%
df_mt.head(20)
# Out:
#    movieID releaseYear                                              title  \
# 0        1        2003                                    Dinosaur Planet
# 1        2        2004                         Isle of Man TT 2004 Review
# 2        3        1997                                          Character
# 3        4        1994                       Paula Abdul's Get Up & Dance
# 4        5        2004                           The Rise and Fall of ECW
# 5        6        1997                                               Sick
# 6        7        1992                                              8 Man
# 7        8        2004                         What the #$*! Do We Know!?
# 8        9        1991                           Class of Nuke 'Em High 2
# 9       10        2001                                            Fighter
# 10      11        1999                     Full Frame: Documentary Shorts
# 11      12        1947                               My Favorite Brunette
# 12      13        2003  Lord of the Rings: The Return of the King: Ext...
# 13      14        1982                                 Nature: Antarctica
# 14      15        1988                   Neil Diamond: Greatest Hits Live
# 15      16        1996                                          Screamers
# 16      17        2005                                          7 Seconds
# 17      18        1994                                   Immortal Beloved
# 18      19        2000                              By Dawn's Early Light
# 19      20        1972                                    Seeta Aur Geeta
#
#      type                                           keywords
# 0   movie                                 [dinosaur, planet]
# 1   movie                             [isl, man, tt, review]
# 2   movie                                          [charact]
# 3   movie                          [paula, abdul, get, danc]
# 4   movie                                  [rise, fall, ecw]
# 5   movie                                             [sick]
# 6   movie                                              [man]
# 7   movie                                             [know]
# 8   movie                                [class, nuke, high]
# 9   movie                                          [fighter]
# 10  movie                  [full, frame, documentari, short]
# 11  movie                                 [favorit, brunett]
# 12  movie  [lord, ring, return, king, extend, edit, bonu,...
# 13  movie                                [natur, antarctica]
# 14  movie               [neil, diamond, greatest, hit, live]
# 15  movie                                         [screamer]
# 16  movie                                           [second]
# 17  movie                                    [immort, belov]
# 18  movie                               [dawn, earli, light]
# 19  movie                                [seeta, aur, geeta]

# %% [markdown]
# ### Merge the imported datasets into one based on movieID

# %%
df = df_input.merge(df_mt)
df.drop('index', axis = 1, inplace=True)

# %%
df.head()
# Out:
#     userID  rating  ratingDate movieID releaseYear            title   type  \
# 0  1488844     3.0  2005-09-06       1        2003  Dinosaur Planet  movie
# 1   822109     5.0  2005-05-13       1        2003  Dinosaur Planet  movie
# 2   885013     4.0  2005-10-19       1        2003  Dinosaur Planet  movie
# 3    30878     4.0  2005-12-26       1        2003  Dinosaur Planet  movie
# 4   823519     3.0  2004-05-03       1        2003  Dinosaur Planet  movie
#
#              keywords
# 0  [dinosaur, planet]
# 1  [dinosaur, planet]
# 2  [dinosaur, planet]
# 3  [dinosaur, planet]
# 4  [dinosaur, planet]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100480507 entries, 0 to 100480506
# Data columns (total 8 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   userID       object
#  1   rating       float64
#  2   ratingDate   object
#  3   movieID      object
#  4   releaseYear  object
#  5   title        object
#  6   type         object
#  7   keywords     object
# dtypes: float64(1), object(7)
# memory usage: 6.7+ GB

# %% [markdown]
# ### How many NaN values in each column?

# %%
for column in df.columns:
    print("NaN sum in column:", column, "equals", df[column].isna().sum())
# Out:
# NaN sum in column: userID equals 0
# NaN sum in column: rating equals 0
# NaN sum in column: ratingDate equals 0
# NaN sum in column: movieID equals 0
# NaN sum in column: releaseYear equals 0
# NaN sum in column: title equals 0
# NaN sum in column: type equals 0
# NaN sum in column: keywords equals 0

# %%
numeric_cols = ['userID', 'rating', 'movieID', 'releaseYear']

# %%
## Are all values in numeric columns numbers?

for column in numeric_cols:
    print("NaN sum in column when numeric:", column, "equals", pd.to_numeric(df[column], errors='coerce').isna().sum())
# Out:
# NaN sum in column when numeric: userID equals 0
# NaN sum in column when numeric: rating equals 0
# NaN sum in column when numeric: movieID equals 0
# NaN sum in column when numeric: releaseYear equals 965

# %%
## Which rows contain non-numeric values in column 'releaseYear'?

year_index = list(df.loc[pd.isna(pd.to_numeric(df['releaseYear'], errors='coerce')), :].index)
len(year_index)
# Out:
# 965

# %%
## Which titles miss the 'release year' information?

df.loc[year_index, 'title'].value_counts()
# Out:
# Ancient Civilizations: Athens and Greece       195
# Ancient Civilizations: Rome and Pompeii        189
# Jimmy Hollywood                                189
# Eros Dance Dhamaka                             116
# Ancient Civilizations: Land of the Pharaohs    113
# Hote Hote Pyaar Ho Gaya                         88
# Roti Kapada Aur Makaan                          75
# Name: title, dtype: int64

# %%
df.loc[year_index, :].sample(n=10)
# Out:
#            userID  rating  ratingDate movieID releaseYear  \
# 93991314  2439493     1.0  2005-03-10   16678        NULL
# 58726816  2195326     3.0  2000-12-09   10782        NULL
# 23435151  2126435     3.0  2004-08-21    4388        NULL
# 23435071   573434     3.0  2005-09-28    4388        NULL
# 93991401   305344     1.0  2004-10-15   16678        NULL
# 41122100  2242431     4.0  2003-11-20    7241        NULL
# 23435177    30298     1.0  2004-05-25    4388        NULL
# 58726847  1514144     4.0  2004-09-20   10782        NULL
# 89557170   724374     2.0  2005-10-29   15918        NULL
# 58726795  1282495     3.0  2004-03-25   10782        NULL
#
#                                              title   type  \
# 93991314                           Jimmy Hollywood  movie
# 58726816                    Roti Kapada Aur Makaan  movie
# 23435151   Ancient Civilizations: Rome and Pompeii  movie
# 23435071   Ancient Civilizations: Rome and Pompeii  movie
# 93991401                           Jimmy Hollywood  movie
# 41122100  Ancient Civilizations: Athens and Greece  movie
# 23435177   Ancient Civilizations: Rome and Pompeii  movie
# 58726847                    Roti Kapada Aur Makaan  movie
# 89557170                   Hote Hote Pyaar Ho Gaya  movie
# 58726795                    Roti Kapada Aur Makaan  movie
#
#                                  keywords
# 93991314               [jimmi, hollywood]
# 58726816      [roti, kapada, aur, makaan]
# 23435151  [ancient, civil, rome, pompeii]
# 23435071  [ancient, civil, rome, pompeii]
# 93991401               [jimmi, hollywood]
# 41122100   [ancient, civil, athen, greec]
# 23435177  [ancient, civil, rome, pompeii]
# 58726847      [roti, kapada, aur, makaan]
# 89557170    [hote, hote, pyaar, ho, gaya]
# 58726795      [roti, kapada, aur, makaan]

# %%
## Get the titles of movies with NaN values

null_ids = df.loc[year_index, 'title'].value_counts()
null_ids = null_ids.reset_index()

# %%
## Set the release year value on Google-based information

df.loc[df.title == null_ids['index'].unique()[2], 'releaseYear'] = 1994
df.loc[df.title == null_ids['index'].unique()[3], 'releaseYear'] = 1999
df.loc[df.title == null_ids['index'].unique()[5], 'releaseYear'] = 1999
df.loc[df.title == null_ids['index'].unique()[6], 'releaseYear'] = 1974

# %%
## Set the release year based on the earliest rating date corresponding to the movie

df.ratingDate = pd.to_datetime(df['ratingDate'])

for movie in null_ids['index'].unique()[[0,1,4]]:
    df.loc[df.title == movie, 'releaseYear'] = min(df.loc[df['title'] == movie, 'ratingDate']).year

# %%
df.loc[year_index, :].sample(n=10)
# Out:
#             userID  rating ratingDate movieID releaseYear  \
# 100076064   780058     5.0 2004-10-13   17667        1999
# 23435021   2493000     2.0 2005-11-14    4388        2001
# 41122031   2082114     3.0 2002-08-14    7241        2001
# 25799151    851671     3.0 2003-04-01    4794        2001
# 41121953   1048128     3.0 2003-10-06    7241        2001
# 93991317   1824389     2.0 2005-12-21   16678        1994
# 58726798   1153564     4.0 2000-12-28   10782        1974
# 58726787    472483     1.0 2005-08-03   10782        1974
# 23435154   1415862     3.0 2003-04-23    4388        2001
# 93991311   2588107     3.0 2005-05-17   16678        1994
#
#                                                  title   type  \
# 100076064                           Eros Dance Dhamaka  movie
# 23435021       Ancient Civilizations: Rome and Pompeii  movie
# 41122031      Ancient Civilizations: Athens and Greece  movie
# 25799151   Ancient Civilizations: Land of the Pharaohs  movie
# 41121953      Ancient Civilizations: Athens and Greece  movie
# 93991317                               Jimmy Hollywood  movie
# 58726798                        Roti Kapada Aur Makaan  movie
# 58726787                        Roti Kapada Aur Makaan  movie
# 23435154       Ancient Civilizations: Rome and Pompeii  movie
# 93991311                               Jimmy Hollywood  movie
#
#                                   keywords
# 100076064             [ero, danc, dhamaka]
# 23435021   [ancient, civil, rome, pompeii]
# 41122031    [ancient, civil, athen, greec]
# 25799151   [ancient, civil, land, pharaoh]
# 41121953    [ancient, civil, athen, greec]
# 93991317                [jimmi, hollywood]
# 58726798       [roti, kapada, aur, makaan]
# 58726787       [roti, kapada, aur, makaan]
# 23435154   [ancient, civil, rome, pompeii]
# 93991311                [jimmi, hollywood]

# %% [markdown]
# ### Save the cleaned data to pickle

# %%
df.to_pickle("input_data.pkl")
